# %%
# !pip3 install matplotlib

# %%
# !pip3 install loguru

# %%
# !pip3 install pandas

# %%
# !python3 main.py -p ./benchmark/E-n22-k4.evrp -a SA -o ./result/SA/ -n 20 --seed 12137

# %%
# !python3 main.py -p ./benchmark/E-n22-k4.evrp -a GSGA -o ./result/GSGA/ -n 10 --seed 12137

# %%
# !python3 main.py -p ./benchmark/E-n22-k4.evrp -a ACO -o ./result/ACO/ -n 10 --seed 12137

# %%
# !python3 main.py -p ./benchmark/E-n22-k4.evrp -a PSO -o ./result/PSO/ -n 10 --seed 12137

# %%
# !python3 main.py -p ./benchmark/E-n22-k4.evrp -a MILP -o ./result/MILP/ -n 10 --seed 12137
